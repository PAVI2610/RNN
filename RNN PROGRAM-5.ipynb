# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# Define the number of timesteps and the number of features
timesteps = 10
features = 5

# Define the RNN model
model = Sequential()
model.add(SimpleRNN(10, input_shape=(timesteps, features)))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Generate some dummy data
import numpy as np
X = np.random.random((1000, timesteps, features))
y = np.random.randint(2, size=(1000, 1))

# Train the model
model.fit(X, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 3s 7ms/step - loss: 0.7024 - accuracy: 0.5040
# Epoch 2/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.7001 - accuracy: 0.5190
# Epoch 3/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6987 - accuracy: 0.5060
# Epoch 4/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6986 - accuracy: 0.5200
# Epoch 5/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6969 - accuracy: 0.5140
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.5230
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.5230
# Epoch 8/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5310
# Epoch 9/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6927 - accuracy: 0.5230
# Epoch 10/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6917 - accuracy: 0.5360
